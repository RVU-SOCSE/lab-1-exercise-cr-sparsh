# %%
a=int(input("enter a"))
b=int(input("enter b"))
print("sum",a+b)
print("sub",a-b)
print("divide",a/b)
print("multiply",a*b)
# Out:
# enter a 3
# enter b 4
# sum 7
# sub -1
# divide 0.75
# multiply 12
